# %% [markdown]
# # Построение модели линейной регрессии

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Снова рассмотрим пример функции $y=cos(1.5\pi sin(x))$. Сгенерируем 30 точек, на которых будем обучать модель линейной регрессии.

# %%
def true_fun(x):
    return np.cos(1.5 * np.pi * np.sin(x))

n_samples = 30

X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

# %%
plt.rcParams['figure.figsize'] = (7,4)
plt.scatter(X, y, edgecolor='b', label='Samples')
plt.xlim(0, 1)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## 1. Линейная регрессия в sklearn

# %% [markdown]
# В библиотеке **Scikit-learn** (sklearn) находится множество реализаций инструментов анализа данных и алгоритмов машинного обучения. Среди алгоритмов можно найти и модель линейной регрессии, которая находится в `sklearn.linear_model`:

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Механизм создания и обучения модели схож с тем, как это реализовано в Prophet. Сначала необходимо инициализировать модель в отдельную переменную, затем обучить ее на имеющейся выборке. В `Prophet` экзогенные переменные можно было добавлять в таблицу, содержащую целевую переменную. Что касается `LinearRegression`, то в нее необходимо передать отдельно матрицу объекты-признаки `X` и целевую переменную `y`. Обучим модель линейной регрессии на имеющейся выборке. Поскольку `sklearn` требует, что первый аргумент в `fit` был матрицей, переведем имеющийся вектор `X` в матрицу с помощью функции `reshape`:

# %%
X = X.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Визуализируем полученную модель. Для этого создадим 100 точек на том же интервале и оценим целевую переменную для них с помощью функции `predict`:

# %%
X_test = np.linspace(0, 1, 100).reshape(-1, 1)

# %%
predictions = model.predict(X_test)

# %%
plt.plot(X_test, predictions, label='Model')
plt.plot(X_test, true_fun(X_test), label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(0, 1)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# Очевидно, сложность модели недостаточная, наблюдается неодообучение. Построим полиномиальную регрессию.

# %% [markdown]
# ## 2. Полиномиальная регрессия

# %% [markdown]
# Библиотека `sklearn` содержит множество методов подготовки данных для анализа и построения моделей. Чтобы построить полиномиальную регрессию, необходимо создать матрицу объекты-признаки вида $1, x, x^2,...$
#
# Чтобы получить такую матрицу, можно воспользоваться функцией `PolynomialFeatures` из модуля `preprocessing`.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Преобразование данных (в нашем случае преобразование $x$ в  $1, x, x^2,...$) осуществляется аналогичным построению моделей образом с помощью функции `fit`. Получим матрицу для построения полиномиальной регрессии третьего порядка:

# %%
polynomial_features = PolynomialFeatures(degree=3)
polynomial_features.fit(X)
# Out:
# PolynomialFeatures(degree=3)

# %% [markdown]
# По умолчанию, если исходная матрица содержит несколько признаков, то кроме степеней будут созданы также колонки с всевозможными комбинациями этих признаков, например, при имеющихся признаках `[a, b]` и степенью `degree=2` результатом работы функции будет матрица `[1, a, b, a^2, ab, b^2]`.

# %% [markdown]
# Чтобы получить результат преобразования, необходимо последовательно применить функции `fit` и `transform` или же сразу `fit_transform`:

# %%
X_poly = polynomial_features.transform(X)

# %%
np.all(X_poly == polynomial_features.fit_transform(X))
# Out:
# True

# %%
X_poly[:10]
# Out:
# array([[1.00000000e+00, 9.09141887e-02, 8.26538970e-03, 7.51441199e-04],
#        [1.00000000e+00, 9.86161150e-02, 9.72513815e-03, 9.59055342e-04],
#        [1.00000000e+00, 1.34716070e-01, 1.81484196e-02, 2.44488376e-03],
#        [1.00000000e+00, 1.47945762e-01, 2.18879486e-02, 3.23822925e-03],
#        [1.00000000e+00, 1.65960764e-01, 2.75429753e-02, 4.57105324e-03],
#        [1.00000000e+00, 1.69371662e-01, 2.86867599e-02, 4.85872420e-03],
#        [1.00000000e+00, 2.39826989e-01, 5.75169847e-02, 1.37941253e-02],
#        [1.00000000e+00, 2.53253511e-01, 6.41373407e-02, 1.62430067e-02],
#        [1.00000000e+00, 2.85234474e-01, 8.13587051e-02, 2.32063075e-02],
#        [1.00000000e+00, 2.88215592e-01, 8.30682272e-02, 2.39415583e-02]])

# %% [markdown]
# Построим теперь модель на полученной матрице:

# %%
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_test_poly = polynomial_features.transform(X_test)
plt.plot(X_test, model.predict(X_test_poly), label='Model')
plt.plot(X_test, true_fun(X_test), label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(0, 1)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## 3. Оценка качества модели

# %% [markdown]
# ### 3.1. Метрики качества

# %% [markdown]
# В sklearn реализовано большое количество метрик качества, в т.ч. MSE, MAE, R2. Все они находятся в модуле `sklearn.metrics`:

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %% [markdown]
# На вход каждая из этих функций принимает две переменные: истинные значения `y_true` и предсказанные `y_pred`:

# %%
mean_squared_error(true_fun(X_test), model.predict(X_test_poly))
# Out:
# 0.006347459897063888

# %%
mean_absolute_error(true_fun(X_test), model.predict(X_test_poly))
# Out:
# 0.053939623578329085

# %%
explained_variance_score(true_fun(X_test), model.predict(X_test_poly))
# Out:
# 0.9888505205284457

# %% [markdown]
# ### 3.2. Отложенная выборка

# %% [markdown]
# Для создания отложенной выборки в sklearn предусмотрен модуль `model_selection` и функция `train_test_split` из него. По умолчанию `train_test_split` разбивает выборку последовательно, то есть более поздние наблюдения окажутся в тестовой выборке. Опция `test_size` позволяет задать долю наблюдений, которая окажется в тестовой выборке:

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
X_train.shape, X_test.shape
# Out:
# ((20, 1), (10, 1))

# %% [markdown]
# Если же нет привязки ко времени, то можно сначала перемешать выборку, указав `shuffle=True` и задав `random_state`, чтобы зафиксировать разбиение.

# %%
#пример
# train_test_split(X, y, test_size=0.33, shuffle=True, random_state=42)

# %% [markdown]
# ### 3.3. Кросс-валидация

# %% [markdown]
# Для оценки качества на кросс-валидации воспользуемся функцией `cross_val_score` из того же модуля `model_selection`. На вход данной функции требуется передать модель, обучающую выборку, также можно указать метрику качества и число блоков разбиения:

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
# Out:
# array([-0.28773401, -0.01428698, -0.12536637, -0.19132347, -0.88868814])

# %% [markdown]
# Принято в `cv` передавать не количество блоков, а генератор разбиения `KFold`, в котором задается число блоков, а также фиксируется само разбиение:

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=kf)
# Out:
# array([-0.1052777 , -0.11848623, -0.04559125, -0.13266405, -0.10468614])

# %% [markdown]
# В результате получили 5 оценок на каждом из блоков.

# %%
_.mean(), _.std()
# Out:
# (-0.10134107338282779, 0.029697861070011)

# %% [markdown]
# Обратите внимание, что `cross_val_score` выдает значение метрики качества со знаком минус. В `scoring` название метрики качества передавалось с приставкой `neg`. Это связано с особенностями реализации методов в sklearn. Считается, что чем больше значение метрики качества, тем лучше.

# %% [markdown]
# ### 3.4. Кросс-валидация на временных рядах

# %% [markdown]
# Как выяснилось ранее, кросс-валидация на временных рядах имеет свои особенности. Для ее проведения также используется функция `cross_val_score`, однако в `cv` передается генератор разбиения `sklearn.model_selection.TimeSeriesSplit`.

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tss = TimeSeriesSplit(n_splits=5)

# %%
#пример
# cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=tss)

# %% [markdown]
# ## 4. Pipeline

# %% [markdown]
# Функция `Pipeline` позволяет последовательно выполнять преобразования над данными. Нет необходимости сначала создавать полиномиальные признаки, затем строить модель, достаточно передавать в готовый `Pipeline` исходные данные.

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([('polynomial_features', polynomial_features),
                     ('linear_regression', model)])

# %%
pipeline.fit(X, y)
X_test = np.linspace(0, 1, 100).reshape(-1, 1)
plt.plot(X_test, pipeline.predict(X_test), label='Model')
plt.plot(X_test, true_fun(X_test), label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(0, 1)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## 5. Гребневая регрессия, лассо регрессия

# %% [markdown]
# Рассмотрим полиномы различных степеней для решения представленной задачи. Для сравнения оценим качество моделей на кросс-валидации по 10 блокам с помощью метрики MSE.

# %%
plt.rcParams['figure.figsize'] = (14,5)
degrees = [1, 4, 15]

for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i+1)

    polynomial_features = PolynomialFeatures(degree=degrees[i])
    model = LinearRegression()
    pipeline = Pipeline([('polynomial_features', polynomial_features),
                         ('linear_regression', model)])
    pipeline.fit(X, y)

    scores = cross_val_score(pipeline, X, y, scoring='neg_mean_squared_error', cv=10)

    plt.plot(X_test, pipeline.predict(X_test), label='Model')
    plt.plot(X_test, true_fun(X_test), label='True function')
    plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
    plt.xlim(0, 1)
    plt.ylim(-2, 2)
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(
        degrees[i], -scores.mean(), scores.std()))

plt.show()

# %% [markdown]
# Для противодействия переобучению прибегают к гребневой или лассо регрессиям. Они также находятся в модуле `sklearn.linear_model`:

# %%
from sklearn.linear_model import Ridge, Lasso

# %% [markdown]
# ### 5.1. Гребневая регрессия

# %% [markdown]
# При инициализации модели есть возможность указать значение параметра регуляризации. В `sklearn` это `alpha`. По умолчаю в `Ridge` значение параметра регуряризации равно 1.

# %%
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i+1)

    polynomial_features = PolynomialFeatures(degree=degrees[i])
    model = Ridge(alpha=1)
    
    pipeline = Pipeline([('polynomial_features', polynomial_features),
                         ('linear_regression', model)])
    
    pipeline.fit(X, y)

    scores = cross_val_score(pipeline, X, y, scoring='neg_mean_squared_error', cv=10)

    plt.plot(X_test, pipeline.predict(X_test), label='Model')
    plt.plot(X_test, true_fun(X_test), label='True function')
    plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
    plt.xlim(0, 1)
    plt.ylim(-2, 2)
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(degrees[i], -scores.mean(), scores.std()))
    
plt.show()

# %% [markdown]
# Как видно из примера, при значении $\lambda=1$ регуляризация слишком сильная и необходимо выбрать другое значение для улучшения качества аппроксимации.

# %% [markdown]
# ### 5.3. Лассо регрессия

# %% [markdown]
# Рассмотрим модель лассо регрессии. Также убедимся, что регуляризация оказалась слишком сильной для данной задачи, и решение свелось к константе.

# %%
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i+1)

    polynomial_features = PolynomialFeatures(degree=degrees[i])
    model = Lasso(alpha=1)
    
    pipeline = Pipeline([('polynomial_features', polynomial_features),
                         ('linear_regression', model)])
    
    pipeline.fit(X, y)

    scores = cross_val_score(pipeline, X, y, scoring='neg_mean_squared_error', cv=10)

    plt.plot(X_test, pipeline.predict(X_test), label='Model')
    plt.plot(X_test, true_fun(X_test), label='True function')
    plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
    plt.xlim(0, 1)
    plt.ylim(-2, 2)
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(degrees[i], -scores.mean(), scores.std()))
    
plt.show()

# %% [markdown]
# Выберем `alpha=0.01`:

# %%
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i+1)

    polynomial_features = PolynomialFeatures(degree=degrees[i])
    model = Lasso(alpha=0.01)
    
    pipeline = Pipeline([('polynomial_features', polynomial_features),
                         ('linear_regression', model)])
    
    pipeline.fit(X, y)

    scores = cross_val_score(pipeline, X, y, scoring='neg_mean_squared_error', cv=10)

    plt.plot(X_test, pipeline.predict(X_test), label='Model')
    plt.plot(X_test, true_fun(X_test), label='True function')
    plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
    plt.xlim(0, 1)
    plt.ylim(-2, 2)
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(degrees[i], -scores.mean(), scores.std()))
    
plt.show()

# %% [markdown]
# Видно, что регуляризация помогла избежать переобучения, однако лассо регрессия здесь не лучший вариант. Посмотрим на соответствующие коэффициенты модели:

# %%
model.coef_
# Out:
# array([ 0.        , -2.85431207, -0.        ,  0.        ,  0.        ,
#         0.        ,  1.01672317,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        ])

# %% [markdown]
# Большая часть коэффициентов оказались равными нулю. Таким образом, лассо регрессия позволяет отбирать наиболее значимые признаки.

# %% [markdown]
# ## 6. Выбор параметра регуляризации $\lambda$

# %% [markdown]
# Как было отмечено ранее, параметр регуляризации может быть выбран на кросс-валидации. Такой прием реализован в функции `sklearn.model_selection.GridSearchCV`. На вход ей необходимо передать словарь параметров, которые нужно перебрать: их названия и значения. Выбор параметров также реализован через функцию `fit`.

# %%
from sklearn.model_selection import GridSearchCV

# %%
alpha_list = {'alpha': [0, 0.01, 0.1, 0.5, 1]}

# %%
X_poly = polynomial_features.transform(X)

# %%
model = Ridge()

# %%
gs = GridSearchCV(model, alpha_list, scoring='neg_mean_squared_error', cv=kf)

# %%
gs.fit(X_poly, y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Ridge(), param_grid={'alpha': [0, 0.01, 0.1, 0.5, 1]},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# Лучшую модель, оптимальные по заданной метрике значения параметров и само значение метрики качества можно получить после обучения `GridSearchCV`:

# %%
gs.best_estimator_
# Out:
# Ridge(alpha=0.01)

# %%
gs.best_params_
# Out:
# {'alpha': 0.01}

# %%
gs.best_score_
# Out:
# -0.014091190712668247

# %% [markdown]
# Посмотрим на результаты с новым значением параметра регуляризации:

# %%
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i+1)

    polynomial_features = PolynomialFeatures(degree=degrees[i])
    model = Ridge(alpha=0.01)
    
    pipeline = Pipeline([('polynomial_features', polynomial_features),
                         ('linear_regression', model)])
    
    pipeline.fit(X, y)

    scores = cross_val_score(pipeline, X, y, scoring='neg_mean_squared_error', cv=10)

    plt.plot(X_test, pipeline.predict(X_test), label='Model')
    plt.plot(X_test, true_fun(X_test), label='True function')
    plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
    plt.xlim(0, 1)
    plt.ylim(-2, 2)
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(degrees[i], -scores.mean(), scores.std()))
    
plt.show()

# %% [markdown]
# Несмотря на то, что была выбрана довольно высокая степень полинома, это не привело к переобучению.
#
# Если подбор параметров осуществляется внутри `Pipeline`, то нужно указать полный "путь" параметра через двойное нижнее подчеркивание:

# %%
pipeline = Pipeline([('polynomial_features', polynomial_features),
                     ('ridge', model)])

# %%
params = {'polynomial_features__degree': [2, 3, 4, 8, 15], 
          'ridge__alpha': [0, 0.01, 0.1, 0.5, 1]}

# %%
gs = GridSearchCV(pipeline, params, scoring='neg_mean_squared_error', cv=kf)

# %%
gs.fit(X, y)
gs.best_estimator_
# Out:
# Pipeline(steps=[('polynomial_features', PolynomialFeatures(degree=15)),
#                 ('ridge', Ridge(alpha=0.01))])

# %%
gs.best_params_
# Out:
# {'polynomial_features__degree': 15, 'ridge__alpha': 0.01}

# %% [markdown]
# <div class="alert alert-info">
#
# <h4> Задание</h4>
# <p></p>
#
# Сгенерируйте 150 точек $(x,y)$ по следующему правилу: $y=10сos(1.5 sin(x))$ и добавьте к целевой переменной $y$ случайный шум из нормального распределения с отклонением $\sigma=0.5$. Разбейте выборку на обучение и контроль в соотношении 2:1.
# <ol>
# <li>Методом наименьших квадратов по обучающей выборке постройте полиномиальную регрессию достаточно высокого порядка (например, 15-20), визуализируйте полученную модель и оцените MSE на отложенной выборке.</li>
# <li>Постройте гребневую регрессию. Методом кросс-валидации (GridSearchCV) выберите оптимальный параметр $\lambda$ (alpha в функции Ridge). Получите предсказания полученной моделью для тестовой выборки и оцените качество предсказаний.</li>
#
# <li>Постройте лассо-регрессию. Методом кросс-валидации выберите оптимальный параметр $\lambda$.  Получите предсказания полученной моделью для тестовой выборки и оцените качество предсказаний.</li>
# <li>Сравните качество результатов визуально и с помощью MSE.</li>
#
# </ol>
#
# <p></p>
# </div>

# %%
def true_fun(x):
    return 10*np.cos(1.5 * np.sin(x))

n_samples = 150

X = np.linspace(-2,2,150)
y = true_fun(X) + np.random.normal(size=n_samples,scale=0.5)

# %%
plt.plot(y)

# %%
X = X.reshape(-1, 1)

# %%
plt.rcParams['figure.figsize'] = (7,4)
plt.scatter(X, y, edgecolor='b', label='Samples')
plt.xlim(-2, 2)
plt.ylim(0, 15)
plt.show()

# %% [markdown]
# ###### Разбиение

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
X_train.shape, X_test.shape
# Out:
# ((100, 1), (50, 1))

# %%
polynomial_features = PolynomialFeatures(degree=15)
polynomial_features = polynomial_features.fit(X_train)

# %%
X_poly = polynomial_features.transform(X_train)

# %%
model = LinearRegression()
model.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly = polynomial_features.transform(X_test)
X_sort, y_sort = zip(*sorted(list(zip(X_test,model.predict(X_test_poly)))))
plt.plot(X_sort, y_sort, label='Model')

# %%
X_test, Y_test = zip(*sorted(list(zip(X_test, true_fun(X_test)))))

# %%
plt.plot(X_sort, y_sort, label='Model')
plt.plot(X_test, Y_test, label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(-2, 2)
plt.ylim(0, 15)
plt.show()

# %%
mean_squared_error(Y_test, y_sort)
# Out:
# 0.18421318170963502

# %% [markdown]
# ###### Гребневая регрессия

# %%
alpha_list = {'alpha': [0, 0.01,  0.05, 0.1, 0.15, 0.5, 1]}

# %%
model = Ridge()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
gs = GridSearchCV(model, alpha_list, scoring='neg_mean_squared_error', cv=kf)

# %%
gs.fit(X_poly, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Ridge(),
#              param_grid={'alpha': [0, 0.01, 0.05, 0.1, 0.15, 0.5, 1]},
#              scoring='neg_mean_squared_error')

# %%
gs.best_estimator_
# Out:
# Ridge(alpha=0.05)

# %%
gs.best_score_
# Out:
# -2.66323269786454

# %%
ridge_model = Ridge(alpha=0.05)
ridge_model.fit(X_poly, y_train)
# Out:
# Ridge(alpha=0.05)

# %%
polynomial_features = PolynomialFeatures(degree=15)

# %%
polynomial_features=polynomial_features.fit(X_train)

# %%
X_test_poly = polynomial_features.transform(X_train)

# %%
X_sort, y_sort = zip(*sorted(list(zip(X_test, ridge_model.predict(X_test_poly)))))
X_test, Y_test = zip(*sorted(list(zip(X_test, true_fun(X_test)))))
plt.plot(X_sort, y_sort, label='Model')
plt.plot(X_test, Y_test, label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(-2, 2)
plt.ylim(0, 15)
plt.legend()
plt.show()

# %%
mean_squared_error(Y_test, y_sort)
# Out:
# 22.251615365343756

# %% [markdown]
# ###### Лассо регрессия

# %%
alpha_list = {'alpha': [0, 0.01,  0.05, 0.1, 0.15, 0.5, 1]}

# %%
model = Lasso()

# %%
gs = GridSearchCV(model, alpha_list, scoring='neg_mean_squared_error', cv=kf)

# %%
gs.fit(X_poly, y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.161147398786888, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.732237745293247, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.753945961701278, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.091664388356111, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.80983761787487, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.59295299157134, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.97383122184963, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.03947704425149, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.73156949241779, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.85463896160247, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.50384198777749, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.512184813930205, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.77796835301888, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.71860867732296, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.93419179106395, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.22541491932226, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.23703086938971, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.25797132405657, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.104570629890155, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.049744290078834, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.391411419396086, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.885843526148136, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.534827998131775, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.23745121196206, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.400056523375255, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150.3159353459037, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141.98937113764217, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127.00386153887457, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132.4390892380943, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139.3507707632602, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136.91368761457892, tolerance: 0.10187088777129356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 168.0863176073762, tolerance: 0.09926431540105783
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164.8835668178103, tolerance: 0.10192100254936091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160.89659911600143, tolerance: 0.09810667243711217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163.75151686777753, tolerance: 0.09425005614685494
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.268557217041248, tolerance: 0.1241519722790102
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Lasso(),
#              param_grid={'alpha': [0, 0.01, 0.05, 0.1, 0.15, 0.5, 1]},
#              scoring='neg_mean_squared_error')

# %%
gs.best_estimator_
# Out:
# Lasso(alpha=0)

# %%
laso_model = Lasso(alpha=0)
laso_model.fit(X_poly, y_train)
# Out:
# <ipython-input-444-688837384fb5>:2: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   laso_model.fit(X_poly, y_train)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.268557217041248, tolerance: 0.1241519722790102
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0)

# %%
X_test_poly = polynomial_features.transform(X_train)
X_sort, y_sort = zip(*sorted(list(zip(X_test, laso_model.predict(X_test_poly)))))
X_test, Y_test = zip(*sorted(list(zip(X_test, true_fun(X_test)))))
plt.plot(X_sort, y_sort, label='Model')
plt.plot(X_test, Y_test, label='True function')
plt.scatter(X, y, edgecolor='b', s=20, label='Samples')
plt.xlim(-2, 2)
plt.ylim(0, 15)
plt.legend()
plt.show()
